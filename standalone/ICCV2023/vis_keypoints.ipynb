# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("/mnt/sda/datasets/IMCPT/british_museum/dense/images/99586182_328408105.jpg")

# %%
kp = np.load("output/nessst_kp.npy")[..., [1, 0]]

# %%
from source.evaluation.classical.vis import to_cv2_keypoint

plt.figure(figsize=(12,12))
plt.imshow(cv2.drawKeypoints(image, to_cv2_keypoint(kp), None, color=(0,255,0)))
